# %% [markdown]
# <a href="https://colab.research.google.com/github/mdashrafresearch/911124243058-Sem4/blob/main/CN5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scapy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 24.5 MB/s eta 0:00:00
# ...

# %%
import sys
from scapy.all import *

# Define the packet handling function
def packet_handler(packet):
    print(packet.show())

# Capture packets on the network (change interface if needed)
sniff(iface="eth0", prn=packet_handler)
# Out:
# Streaming output truncated to the last 5000 lines.
#         dport     = 45168
#         seq       = 416118904
#         ack       = 3605915138
#         dataofs   = 8
#         reserved  = 0
#         flags     = PA
#         window    = 745
#         chksum    = 0x56f5
#         urgptr    = 0
#         options   = [('NOP', None), ('NOP', None), ('Timestamp', (1262127557, 501014581))]
# ###[ Raw ]###
# ...
